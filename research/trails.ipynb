# %%
import os
os.chdir("../")

# %%
import pandas as pd
df=pd.read_csv("data/Flipkart_Product.csv")

# %%
df.shape
# Out:
# (811, 5)

# %%
df.columns
# Out:
# Index(['ProductName', 'Price', 'Rate', 'Review', 'Summary'], dtype='object')

# %%
# Teh data that is required for creating the application
data=df

# %%
data.shape
# Out:
# (811, 5)

# %%
# Convert to desired data format
product_list=[]

# Iterate over the rows of the data frame
for index,row in data.iterrows():
    # Construct an object with the column, convert to dictionary
    obj = {
        'ProductName': row['ProductName'], 
        'Price':row['Price'], 
        'Rate':row['Rate'], 
        'Review':row['Review'], 
        'Summary':row['Summary']    
    }
    # Append the object to list
    product_list.append(obj)

# %%
obj
# Out:
# {'ProductName': 'NIVEA Soft Light Moisturizer for Face, Hand & Body, Non-Sticky Cream with Vitamin E & Jojoba OilÂ\xa0Â\xa0(100 ml)',
#  'Price': 'â‚¹142',
#  'Rate': '4',
#  'Review': 'Delightful',
#  'Summary': 'Very nice and so soft and cute packing ???i have small pack was just try next time big pack â˜º'}

# %%
product_list # Dictionary present inside list
# Out:
# [{'ProductName': 'Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White, Black, Elegant High Speed-Honey Comb Cooling Pad & Ice Chamber, Blower)',
#   'Price': 'ƒ??3,999',
#   'Rate': '5',
#   'Review': 'Super!',
#   'Summary': "Great cooler.. excellent air flow and for this price. It's so amazing and unbelievable.Just love it ƒ\x9d?‹?\x8f"},
#  {'ProductName': 'Candes 60 L Room/Personal Air Cooler?ÿ?ÿ(White, Black, CRETA)',
#   'Price': 'ƒ??8,999',
#   'Rate': '5',
#   'Review': 'Great product',
#   'Summary': 'Beautiful product good material and perfectly working'},
#  {'ProductName': 'MAHARAJA WHITELINE 65 L Desert Air Cooler?ÿ?ÿ(White, Grey, Rambo Grey / AC-303)',
#   'Price': 'ƒ??7,999',
#   'Rate': '5',
#   'Review': 'Wonderful',
#   'Summary': 'The best poduct that i bought from flifkart it works superb like ac and price is also reasonable only rs 8698'},
#  {'ProductName': 'Crompton 75 L Desert Air Cooler?ÿ?ÿ(White, Teal, ACGC-DAC751)',
#   'Price': 'ƒ??9,999',
#   'Rate': '5',
# ...

# %%
# Print the list of objects
for obj in product_list:
    print(obj)
# Out:
# {'ProductName': 'Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White, Black, Elegant High Speed-Honey Comb Cooling Pad & Ice Chamber, Blower)', 'Price': 'ƒ??3,999', 'Rate': '5', 'Review': 'Super!', 'Summary': "Great cooler.. excellent air flow and for this price. It's so amazing and unbelievable.Just love it ƒ\x9d?‹?\x8f"}
# {'ProductName': 'Candes 60 L Room/Personal Air Cooler?ÿ?ÿ(White, Black, CRETA)', 'Price': 'ƒ??8,999', 'Rate': '5', 'Review': 'Great product', 'Summary': 'Beautiful product good material and perfectly working'}
# {'ProductName': 'MAHARAJA WHITELINE 65 L Desert Air Cooler?ÿ?ÿ(White, Grey, Rambo Grey / AC-303)', 'Price': 'ƒ??7,999', 'Rate': '5', 'Review': 'Wonderful', 'Summary': 'The best poduct that i bought from flifkart it works superb like ac and price is also reasonable only rs 8698'}
# ...

# %% [markdown]
# # Convert everything to embeddigs

# %%
# First convert everything to documents
from langchain_core.documents import Document
# Create LangChain documents
docs = []
for item in product_list:
    if isinstance(item, dict):  
        ProductName = item.get('ProductName', '')
        text = f"ProductName: {item.get('ProductName', '')} \n Price: {item.get('Price', '')} \n Rating: {item.get('Rate', '')} \n Review: {item.get('Review', '')} \n Summary: {item.get('Summary', '')}"
        metadata = {"ProductName": ProductName}
        document = Document(page_content=text, metadata=metadata)
        docs.append(document)

# %%
docs[0]
# Meta data is product name
#  page content is information This we wil use for embedding
# Out:
# Document(metadata={'ProductName': 'Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White, Black, Elegant High Speed-Honey Comb Cooling Pad & Ice Chamber, Blower)'}, page_content="ProductName: Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White, Black, Elegant High Speed-Honey Comb Cooling Pad & Ice Chamber, Blower) \n Price: ƒ??3,999 \n Rating: 5 \n Review: Super! \n Summary: Great cooler.. excellent air flow and for this price. It's so amazing and unbelievable.Just love it ƒ\x9d?‹?\x8f")
